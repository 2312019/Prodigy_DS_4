# %% [markdown]
# <a href="https://colab.research.google.com/github/2312019/Prodigy_DS_4/blob/main/Prodigy_DS_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Twitter Sentiment Analysis

# %%
import pandas as pd

# %%
# 🔹 Install required library
# !pip install textblob

# 🔹 Import additional libraries
import matplotlib.pyplot as plt
from textblob import TextBlob

# %% [markdown]
# ## Load Datasets

# %%
training_df = pd.read_csv('/content/twitter_training.csv', header=None, names=['Tweet ID', 'Entity', 'Sentiment', 'Tweet content'])
validation_df = pd.read_csv('/content/twitter_validation.csv', header=None, names=['Tweet ID', 'Entity', 'Sentiment', 'Tweet content'])

# %% [markdown]
# ### Training Data (First 5 rows)

# %%
display(training_df.head())
# Out:
#    Tweet ID       Entity Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
#
#                                        Tweet content
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %% [markdown]
# ### Validation Data (First 5 rows)

# %%
display(validation_df.head())
# Out:
#    Tweet ID     Entity   Sentiment  \
# 0      3364   Facebook  Irrelevant
# 1       352     Amazon     Neutral
# 2      8312  Microsoft    Negative
# 3      4371      CS-GO    Negative
# 4      4433     Google     Neutral
#
#                                        Tweet content
# 0  I mentioned on Facebook that I was struggling ...
# 1  BBC News - Amazon boss Jeff Bezos rejects clai...
# 2  @Microsoft Why do I pay for WORD when it funct...
# 3  CSGO matchmaking is so full of closet hacking,...
# 4  Now the President is slapping Americans in the...

# %% [markdown]
# ## Sentiment Analysis with TextBlob

# %%
# Select text column (using 'Tweet content' from the training_df)
text_column = 'Tweet content'

# Function to get sentiment
def get_sentiment(text):
    # Ensure text is treated as a string to avoid errors with non-string data types
    analysis = TextBlob(str(text))
    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity < 0:
        return "Negative"
    else:
        return "Neutral"
